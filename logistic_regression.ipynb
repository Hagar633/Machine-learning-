# %% [markdown]
# <a href="https://colab.research.google.com/github/Hagar633/Machine-learning-/blob/main/logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
df=pd.read_csv('cereal.csv')

df.head()
x= df[['calories','protein']].values
le = LabelEncoder()
y = le.fit_transform(df['type'])

from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(x, y)

print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)

from sklearn.metrics import accuracy_score

y_pred = model.predict(x)
acc = accuracy_score(y, y_pred)
print(f"Accuracy: {acc:.2f}")


plt.scatter(x[:,0], x[:,1], c=y, cmap=plt.cm.Paired)


x_values = [np.min(x[:,0]-5), np.max(x[:,0]+5)]
y_values = -(model.intercept_[0] + np.dot(model.coef_[0][0], x_values)) / model.coef_[0][1]

plt.plot(x_values, y_values, label="Decision Boundary")

plt.xlabel('Weight')
plt.ylabel('Age')
plt.legend()
plt.show()
# Out:
# Coefficients: [[-0.01655386  0.81079574]]
# Intercept: [-3.96322697]
# Accuracy: 0.96

# %%
from google.colab import drive
drive.mount('/content/drive')
